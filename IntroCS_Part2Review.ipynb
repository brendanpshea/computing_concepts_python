# %% [markdown]
# <a href="https://colab.research.google.com/github/brendanpshea/computing_concepts_python/blob/main/IntroCS_Part2Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 2 Review: Python, Algorithms, and Cybersecurity (with Batman and Friends)
#
# This chapter reviews material covered in chapters 5 through 8 in terms of a "Batman" case study. I hope you find it useful!

# %%
# Run this cell to launch my video overview
from IPython.display import YouTubeVideo
YouTubeVideo('zFt0DM3xZ_Y', width=800, height=500)

# %% [markdown]
# ## Algorithms and Programming Languages
# In computer science, algorithms are the fundamental building blocks that shape our digital landscape. Just as Batman unravels the complex puzzles of crime in Gotham City, computer scientists dedicate themselves to unraveling the intricacies of algorithms.
#
# So, what exactly is an algorithm? In simple terms, an **algorithm** is a step-by-step procedure for solving a problem or accomplishing a task. Think of it as a recipe that guides you through a series of instructions to achieve a desired outcome. Algorithms are designed to be efficient, reliable, and effective in tackling computational challenges. In fact, computer science is often defined as the study of algorithms, because they form the core of everything we do with computers.
#
# Now, you might wonder how we express these algorithms in a way that computers can understand. That's where programming languages like Python come into play. These **formal languages** as a bridge between human logic and machine execution. It provides a structured and unambiguous way to convey algorithmic instructions, unlike the ambiguity and nuance of natural languages. Python's clear and concise syntax makes it an ideal choice for expressing algorithms formally.
#
# Let's take a closer look at how a Python program, like the iconic "I am Batman!" statement, goes from source code to execution:
#
# 1. The **source code** is the human-readable version of the program, written in Python. It's like Batman's secret plans, outlining the steps to be executed.
#    ```python
#    print("I am Batman!")
#    ```
#
# 2. The Python **interpreter** analyzes the source code, checking for any syntactical errors or inconsistencies. It's like Batman's loyal butler Alfred deciphering his cryptic messages.
# 3.  Once the code is deemed valid, the interpreter **translates** it into a lower-level language that the computer can comprehend. It's similar to how Batman's plans are communicated to his allies in the field.
# 4.  Finally, the translated code is executed by the computer's hardware, bringing the algorithm to life. It follows the precise steps outlined in the algorithm, manipulating data and producing results. This process is reminiscent of Batman's nightly patrols, where he methodically carries out his plans to maintain order and justice.
#
# As aspiring Pythonistas, you are the vigilantes of the digital world, armed with the knowledge and skills to create, analyze, and optimize algorithms. With each line of code you write, you contribute to the ongoing battle against computational challenges, making the world a better place, one algorithm at a time.

# %% [markdown]
# ![batman_python.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Data Types in the Gotham of Python
#
# Welcome to the Gotham City of Python, where data types reign supreme. Just like the iconic characters that roam the streets of Gotham, each data type has its unique characteristics and abilities. Let's dive into the world of Python data types and explore their powers.
#
# ### Integers (int)
# Integers are the dark knights of Gotham, representing whole numbers without any decimal points. They are strong, reliable, and always ready to fight crime. In Python, you can perform various operations with integers, such as addition, subtraction, multiplication, and division.

# %%
# Integer operations
batman_age = 35
robin_age = 25
total_age = batman_age + robin_age
age_difference = batman_age - robin_age
double_batman_age = batman_age * 2
half_robin_age = robin_age // 2

print("Batman's age:", batman_age)
print("Robin's age:", robin_age)
print("Total age:", total_age)
print("Age difference:", age_difference)
print("Double Batman's age:", double_batman_age)
print("Half Robin's age:", half_robin_age)
# Out:
# Batman's age: 35
# Robin's age: 25
# Total age: 60
# Age difference: 10
# Double Batman's age: 70
# Half Robin's age: 12

# %% [markdown]
# ### Floating-Point Numbers (float)
# Floating-point numbers, or floats, are the silent guardians of Gotham. They are precise and stealthy, representing real numbers with decimal points. Floats are essential when dealing with precise measurements or calculations.

# %%
# Float operations
catwoman_stealth = 9.9
batman_speed = 7.5
total_agility = catwoman_stealth + batman_speed
agility_difference = catwoman_stealth - batman_speed
double_batman_speed = batman_speed * 2
half_catwoman_stealth = catwoman_stealth / 2

print("Catwoman's stealth:", catwoman_stealth)
print("Batman's speed:", batman_speed)
print("Total agility:", total_agility)
print("Agility difference:", agility_difference)
print("Double Batman's speed:", double_batman_speed)
print("Half Catwoman's stealth:", half_catwoman_stealth)
# Out:
# Catwoman's stealth: 9.9
# Batman's speed: 7.5
# Total agility: 17.4
# Agility difference: 2.4000000000000004
# Double Batman's speed: 15.0
# Half Catwoman's stealth: 4.95

# %% [markdown]
# ### Strings (str)
# Strings are the riddles that perplex the villains of Gotham. They are sequences of characters that form words, sentences, or any textual data. In Python, you can manipulate strings using various operations and methods.

# %%
# String operations
joker_quote = "Why so serious?"
batman_reply = "I'm Batman!"
full_dialogue = joker_quote + " " + batman_reply
joker_laugh = "HA" * 3
batman_name = "Bruce Wayne"[0:5]
joker_serious = "serious" in joker_quote

print("Joker's quote:", joker_quote)
print("Batman's reply:", batman_reply)
print("Full dialogue:", full_dialogue)
print("Joker's laugh:", joker_laugh)
print("Batman's name:", batman_name)
print("Is 'serious' in Joker's quote?", joker_serious)
# Out:
# Joker's quote: Why so serious?
# Batman's reply: I'm Batman!
# Full dialogue: Why so serious? I'm Batman!
# Joker's laugh: HAHAHA
# Batman's name: Bruce
# Is 'serious' in Joker's quote? True

# %% [markdown]
# ### Booleans (bool)
# Booleans are the two faces of justice in Gotham, representing the duality of truth and falsehood. They are like Harvey Dent, aka Two-Face, making decisions based on the flip of a coin. In Python, booleans are used for logical operations and comparisons.

# %%
# Boolean operations
is_batman = True
is_joker = False
is_hero = is_batman and not is_joker
is_villain = is_joker or not is_batman
is_same_person = is_batman == is_joker

print("Is Batman?", is_batman)
print("Is Joker?", is_joker)
print("Is hero?", is_hero)
print("Is villain?", is_villain)
print("Is same person?", is_same_person)
# Out:
# Is Batman? True
# Is Joker? False
# Is hero? True
# Is villain? False
# Is same person? False

# %% [markdown]
# ### Lists
# Lists are the utility belts of the Python universe, holding an arsenal of items. They are ordered collections that can store multiple values of different types. Lists are mutable, meaning they can be modified after creation.

# %%
# List operations
batman_gadgets = ["Batarang", "Grappling Hook", "Smoke Pellets"]
joker_weapons = ["Joker Venom", "Acid Flower", "Laughing Gas"]

all_items = batman_gadgets + joker_weapons
num_batman_gadgets = len(batman_gadgets)

print("Batman's gadgets:", batman_gadgets)
print("Joker's weapons:", joker_weapons)
print("All items:", all_items)
print("Number of Batman's gadgets:", num_batman_gadgets)

print("First Batman gadget:", batman_gadgets[0])

batman_gadgets.append("Batmobile")
batman_gadgets.remove("Smoke Pellets")

print("Updated Batman's gadgets:", batman_gadgets)

print("Batman's gadgets:")
for gadget in batman_gadgets:
    print(gadget)
# Out:
# Batman's gadgets: ['Batarang', 'Grappling Hook', 'Smoke Pellets']
# Joker's weapons: ['Joker Venom', 'Acid Flower', 'Laughing Gas']
# All items: ['Batarang', 'Grappling Hook', 'Smoke Pellets', 'Joker Venom', 'Acid Flower', 'Laughing Gas']
# Number of Batman's gadgets: 3
# First Batman gadget: Batarang
# Updated Batman's gadgets: ['Batarang', 'Grappling Hook', 'Batmobile']
# Batman's gadgets:
# Batarang
# Grappling Hook
# Batmobile

# %% [markdown]
# #### How to Print Variables to Screen with `print()` and f-strings
#
# In Python, the `print()` function is used to output text or variables to the console. The function can take multiple arguments and can also format output in various ways. One of the most convenient methods for string formatting is using f-strings, introduced in Python 3.6.
#
# Here's how you can print variables using `print()` and f-strings:

# %%
# Declare variables
batmanAlias = "Bruce Wayne"
riddlerQuestion = "What belongs to you, but other people use it more than you do?"
riddleAnswer = "Your name"

# Using print() to display a single variable
print(batmanAlias)  # Output: Bruce Wayne

# Using print() to display multiple variables
print("Riddler's Question:", riddlerQuestion)

# Using f-strings for formatted output
print(f"The answer to Riddler's question '{riddlerQuestion}' is {riddleAnswer}.")

# Combining text and variables in f-strings
print(f"{batmanAlias}, also known as Batman, solved the riddle: {riddleAnswer}.")
# Out:
# Bruce Wayne
# Riddler's Question: What belongs to you, but other people use it more than you do?
# The answer to Riddler's question 'What belongs to you, but other people use it more than you do?' is Your name.
# Bruce Wayne, also known as Batman, solved the riddle: Your name.

# %% [markdown]
# In the above examples:
#
# -   The `print()` function is used to display the value of the variable `batmanAlias`.
#
# -   Multiple variables are printed by separating them with a comma inside the `print()` function.
#
# -   f-strings are used for formatted output. Inside an f-string, expressions enclosed between curly braces `{}` can be used to embed variables directly into the string. The expressions are evaluated at runtime.
#
# This allows for a more readable and concise way to format and print variables in Python.

# %% [markdown]
# #### How to Get Input and Cast It to the Correct Data Type
#
# In Python, the `input()` function is used to read a line from the standard input (usually the keyboard) and returns it as a string. To convert this string into the desired data type, you can use type casting functions like `int()`, `float()`, and `bool()`.
#
# Here's how you can get input and cast it to the correct data type, using a hypothetical scenario where Batman needs to input some information:

# %%
# Get input as string and store it in a variable
jokerAlias = input("Enter Joker's alias: ")  # Input will be read as a string

# Get numerical input and cast it to integer
jokerCrimes = int(input("Enter the number of crimes Joker has committed: "))  # Input will be cast to an integer

# Get numerical input and cast it to float
jokerHeight = float(input("Enter Joker's height in meters: "))  # Input will be cast to a float

# Get boolean input and cast it to boolean
isJokerInsane = bool(int(input("Is Joker insane? Enter 1 for True and 0 for False: ")))  # Input will be cast to a boolean

# Display the collected information using f-strings
print(f"Joker's alias is {jokerAlias}. He has committed {jokerCrimes} crimes and is {jokerHeight} meters tall. Is he insane? {isJokerInsane}.")
# Out:
# Enter Joker's alias: Joker
# Enter the number of crimes Joker has committed: 6
# Enter Joker's height in meters: 4.3
# Is Joker insane? Enter 1 for True and 0 for False: 1
# Joker's alias is Joker. He has committed 6 crimes and is 4.3 meters tall. Is he insane? True.

# %% [markdown]
# In this example:
#
# -   `input("Enter Joker's alias: ")` captures the alias of the Joker as a string. No type casting is required as the alias is already textual information.
#
# -   `int(input("Enter the number of crimes Joker has committed: "))` captures the input as a string and then casts it to an integer using the `int()` function.
#
# -   `float(input("Enter Joker's height in meters: "))` captures the input as a string and then casts it to a float using the `float()` function.
#
# -   `bool(int(input("Is Joker insane? Enter 1 for True and 0 for False: ")))` captures the input as a string, casts it to an integer using `int()`, and then further casts it to a boolean using `bool()`.
#
# The `print()` function with f-strings is then used to display the collected information, confirming that the inputs have been cast to their appropriate data types.

# %% [markdown]
# #### How to Declare and Use Simple Functions in Python
#
# In Python, a function is a reusable block of code that performs a specific task. Functions are declared using the `def` keyword, followed by the function name and parentheses `()`. The code block within the function is indented.
#
#
# ```python
# def function_name(parameters):
#     # function body
#     return result
# ```

# %% [markdown]
# For example, let's say Barbara Gordon, also known as Oracle, wants a simple function to calculate her age based on her birth year.

# %%
def calculate_age(birth_year):
    current_year = 2023  # Assuming the current year is 2023
    age = current_year - birth_year
    return age

# Usage
oracle_age = calculate_age(1985)
print(f"Oracle's age is {oracle_age}.")
# Out:
# Oracle's age is 38.

# %% [markdown]
# #### Built-in String Methods
#
# Python provides a variety of built-in string methods that can be directly invoked on string objects. For instance, Oracle might frequently use `.upper()` to convert text to uppercase or `.replace()` to replace substrings.

# %%
message = "gotham city"

# Basic String Methods
print(f"Original Message: {message}")
print(f"Uppercase: {message.upper()}")
print(f"Capitalized: {message.capitalize()}")
print(f"Replaced 'city' with 'metropolis': {message.replace('city', 'metropolis')}")

# Combining Methods
print(f"Chained Methods (Uppercase + Replace): {message.upper().replace('CITY', 'METROPOLIS')}")

# Finding Substrings
print(f"Position of 'city' in message: {message.find('city')}")
# Out:
# Original Message: gotham city
# Uppercase: GOTHAM CITY
# Capitalized: Gotham city
# Replaced 'city' with 'metropolis': gotham metropolis
# Chained Methods (Uppercase + Replace): GOTHAM METROPOLIS
# Position of 'city' in message: 7

# %% [markdown]
# ## Mathematical Operations with Python's Math Library
# Given Oracle's penchant for data analysis and cryptography, mathematical operations are indispensable. Python's math library offers a wide range of mathematical functions. Here are five examples:

# %%
import math

# Basic Operations
print(f"Square root of 16: {math.sqrt(16)}")
print(f"15.2 rounded up: {math.ceil(15.2)}")

# Trigonometry
print(f"Sine of pi/2: {math.sin(math.pi / 2)}")

# Logarithms and Exponentiation
print(f"Log base 10 of 100: {math.log(100, 10)}")

# Combining Functions
print(f"Hypotenuse calculated from sides 4 and 3: {math.sqrt(math.pow(4, 2) + math.pow(3, 2))}")
# Out:
# Square root of 16: 4.0
# 15.2 rounded up: 16
# Sine of pi/2: 1.0
# Log base 10 of 100: 2.0
# Hypotenuse calculated from sides 4 and 3: 5.0

# %% [markdown]
# ## Generating Random Numbers with Python's Random Library
# In the realms of cryptography and data sampling, the generation of random numbers is crucial. Python's random library serves this purpose well. Here are five examples:

# %%
import random

# Basic Random Numbers
print(f"Random integer between 1 and 10: {random.randint(1, 10)}")
print(f"Random float between 1.0 and 10.0: {random.uniform(1.0, 10.0)}")

# Random Choice from a List
heroes = ["Raven", "Superman", "Wonder Woman"]
print(f"Random hero from list: {random.choice(heroes)}")

# Shuffling a List
random.shuffle(heroes)
print(f"Shuffled list of heroes: {heroes}")

# Combining Methods
print(f"Random float between sqrt(2) and 3^2: {random.uniform(math.sqrt(2), math.pow(3, 2))}")
# Out:
# Random integer between 1 and 10: 1
# Random float between 1.0 and 10.0: 5.960407438965776
# Random hero from list: Superman
# Shuffled list of heroes: ['Wonder Woman', 'Raven', 'Superman']
# Random float between sqrt(2) and 3^2: 3.694089829756452

# %% [markdown]
# ## Conditionals and Booleans: Decision-Making with Robin and the Teen Titans
# In the realm of programming, conditionals and booleans are indispensable for decision-making. They enable the evaluation of conditions, leading to the execution of specific code blocks depending on the truth value of these conditions. For Robin and the Teen Titans, making quick, informed decisions is crucial in their crime-fighting activities. Let's delve into Python's handling of conditionals and booleans through scenarios that could very well be faced by Robin and his team.
#
# ### Basic if Statement: Is the Team at Full Strength?
# Robin needs to know if the team is at full strength based on the number of available members.

# %%
team_members = 5  # Total team members are 5 when at full strength

if team_members == 5:
    print("The team is at full strength. Time for a mission.")
else:
    print("The team is not at full strength. Proceed with caution.")
# Out:
# The team is at full strength. Time for a mission.

# %% [markdown]
# ##### `elif` Statement: Threat Level Assessment
#
# The Teen Titans need to assess the threat level of an incoming danger. The threat level is categorized as 'Low', 'Medium', or 'High'.

# %%
threat_level = "High"

if threat_level == "Low":
    print("Robin: Titans, this should be easy!")
elif threat_level == "Medium":
    print("Robin: Titans, stay alert!")
else:
    print("Robin: Titans, this is serious. Full power!")
# Out:
# Robin: Titans, this is serious. Full power!

# %% [markdown]
# ##### Nested `if` Statements: Mission Assignment Based on Skills
#
# Each member of the Teen Titans has a unique skill set. Robin wants to assign a mission based on who has the required skills.

# %%
mission_type = "Magic"
cyborg_skills = ["Tech", "Strength"]
raven_skills = ["Magic", "Telekinesis"]

if mission_type in cyborg_skills:
    print("Cyborg, this mission is yours.")
elif mission_type in raven_skills:
    print("Raven, you're up.")
else:
    print("No suitable member for this mission.")
# Out:
# Raven, you're up.

# %% [markdown]
# ##### Combining Booleans: Is the Mission Doable?
#
# Sometimes, the Titans need to decide based on multiple conditions, such as the threat level and the team's strength.

# %%
threat_level = "High"
team_strength = 4  # 1 less than full strength

if threat_level == "High" and team_strength < 5:
    print("Robin: This is a high-threat mission and we're not at full strength. Be extra cautious.")
elif threat_level == "Low" or team_strength == 5:
    print("Robin: We can handle this.")
else:
    print("Robin: Proceed with standard protocols.")
# Out:
# Robin: This is a high-threat mission and we're not at full strength. Be extra cautious.

# %% [markdown]
# By understanding how to use conditionals and booleans, especially those resulting from relational tests like ==, <, or in, Robin and the Teen Titans can make more nuanced decisions. These constructs offer a robust framework for evaluating conditions and determining the team's course of action.

# %% [markdown]
# ## Introduction to Loops in Python
#
# In the programming lexicon, loops are constructs that facilitate the execution of a block of code multiple times, contingent upon certain conditions. They serve as the workhorses of automation, enabling programmers to handle repetitive tasks efficiently. For our hypothetical superheroes, who often find themselves in situations requiring repetitive actions---be it battling an army of clones or disarming a series of traps---loops can serve as a metaphorical framework for understanding their challenges.
#
# Two primary types of loops exist in Python: `while` loops and `for` loops.
#
# ### `while` Loops: The Endurance Test
#
# The `while` loop continues execution as long as a specified condition evaluates to `True`. The syntax is straightforward:
#
# ```python
# while condition:
#     # code to execute
# ```
#
# The loop will keep executing the indented code block as long as `condition` remains true. It's crucial to include an exit condition to prevent infinite loops.
#
# ### `for` Loops: The Precision Strike
#
# The `for` loop is used for iterating over a sequence (list, tuple, dictionary, set, or string). It's like a precision strike where each target must be dealt with individually. The syntax is equally simple:
#
# ```python
# for variable in sequence:
#     # code to execute
# ```
#
# Here, `variable` takes the value of each element in `sequence` one by one, and the indented code block is executed for each value.
#
# ### When to Use Which Loop?
#
# -   Use `while` loops when the number of iterations is unknown or based on a dynamic condition. For example, when the heroes don't know how many enemies they have to defeat.
#
# -   Use `for` loops when the number of iterations is known or predefined. For instance, when the heroes know they have to disarm five bombs.
#
# Understanding the syntax and appropriate use-cases for `while` and `for` loops equips you with a powerful tool for automating repetitive tasks.  Armed with this knowledge, let's delve into specific scenarios involving battles with some appropriatey named villains.

# %% [markdown]
# ### `while` Loop: Defeating Dr. InfiniteLoop
#
# Dr. InfiniteLoop has unleashed an endless army of robots. Our heroes need to keep fighting until their energy reserves are depleted.

# %%
energy_level = 100  # Initial energy level of the Titans

while energy_level > 0:
    print(f"Defeating robots. Energy level: {energy_level}%")
    energy_level -= 10  # Energy decreases by 10% with each iteration
print("Energy depleted. Titans, retreat!")
# Out:
# Defeating robots. Energy level: 100%
# Defeating robots. Energy level: 90%
# Defeating robots. Energy level: 80%
# Defeating robots. Energy level: 70%
# Defeating robots. Energy level: 60%
# Defeating robots. Energy level: 50%
# Defeating robots. Energy level: 40%
# Defeating robots. Energy level: 30%
# Defeating robots. Energy level: 20%
# Defeating robots. Energy level: 10%
# Energy depleted. Titans, retreat!

# %% [markdown]
# ### `for` Loop: Thwarting the Plans of The Enumerator
#
# The Enumerator has planted bombs at multiple locations. We need to defuse them one by one.

# %%
bomb_locations = ["City Hall", "Metro Station", "Museum"]

# Here, we use a for loop to iterate through a list
for location in bomb_locations:
    print(f"Defusing bomb at {location}.")
print("All bombs defused. The Enumerator is defeated!")
# Out:
# Defusing bomb at City Hall.
# Defusing bomb at Metro Station.
# Defusing bomb at Museum.
# All bombs defused. The Enumerator is defeated!

# %% [markdown]
# ### Nested `for` Loop: Battle Against The Combinatrix
#
# The Combinatrix has created multiple barriers, each with several locks. We need to break all the locks on each barrier.

# %%
barriers = ["Fire Barrier", "Ice Barrier"]
locks_per_barrier = 3

# The outer loop involves iterating through a list
for barrier in barriers:
    print(f"Breaking {barrier}.")

    # The inner loops using "range" repeat the appropriate number of times
    for lock in range(locks_per_barrier):
        print(f"  Breaking lock {lock + 1}.") # Python starts counting at 0, so add 1
print("All barriers destroyed. The Combinatrix is defeated!")
# Out:
# Breaking Fire Barrier.
#   Breaking lock 0.
#   Breaking lock 1.
#   Breaking lock 2.
# Breaking Ice Barrier.
#   Breaking lock 0.
#   Breaking lock 1.
#   Breaking lock 2.
# All barriers destroyed. The Combinatrix is defeated!

# %% [markdown]
# ### `for` Loop with `enumerate`: Capturing The Sequencer
#
# The Sequencer has set up a series of traps. We need to know the order in which to disarm them.

# %%
traps = ["Spike Trap", "Gas Trap", "Net Trap"]

# enumerate gives us TWO values--the index number and the actual value
for index, trap in enumerate(traps):
    print(f"Disarming trap {index + 1}: {trap}.")
print("All traps disarmed. The Sequencer is captured!")
# Out:
# Disarming trap 1: Spike Trap.
# Disarming trap 2: Gas Trap.
# Disarming trap 3: Net Trap.
# All traps disarmed. The Sequencer is captured!

# %% [markdown]
# ## Big Idea: Abstraction in Python Programs
#
# In both programming and the real world, abstraction serves as a mechanism to hide complexity while exposing only the essential features. It allows us to manage and understand intricate systems by breaking them down into simpler, more manageable components. For Batman and his allies, abstraction is a tactical approach to problem-solving---whether it's Batman using his utility belt without needing to know how each gadget was engineered, or Oracle coordinating a mission by breaking it down into tasks for each team member.
#
# ### Functions: The Utility Belt of Abstraction
#
# Functions in Python serve as the most straightforward form of abstraction. They encapsulate specific tasks into reusable blocks of code. Just as Batman doesn't need to know the inner workings of every gadget in his utility belt, a programmer using a function doesn't need to understand its internal code to benefit from its functionality.

# %%
# Function to analyze a piece of text for Oracle
def text_analysis(text):
    word_count = len(text.split())
    unique_words = len(set(text.split()))
    return word_count, unique_words

# Oracle can use this function repeatedy without repeating code
# SHe can even allow others to use it, who don't need to know anything about it!
word_count, unique_words = text_analysis("Oracle is the eyes and ears of Batman.")
print(f"Word Count: {word_count}, Unique Words: {unique_words}")
# Out:
# Word Count: 8, Unique Words: 8

# %% [markdown]
# ### Conditionals: Tactical Decision-Making
#
# Conditionals in Python, like `if`, `elif`, and `else`, serve as decision-making tools that abstract away the complexity of evaluating multiple conditions. For instance, Batman might use a conditional thought process to decide which gadget to use based on the situation at hand.

# %%
# Batman deciding which gadget to use
threat_level = "High"

if threat_level == "Low":
    gadget = "Smoke Pellets"
elif threat_level == "Medium":
    gadget = "Batarang"
else:
    gadget = "Explosive Gel"

print(f"Batman will use {gadget}.")

# %% [markdown]
# ### Loops: Automating Repetitive Tasks
#
# Loops, such as `while` and `for`, abstract the repetitive nature of tasks, allowing for efficient execution. Alfred, for example, might use a loop to automate the inventory management of Batman's utility belt.

# %%
# Alfred managing the utility belt inventory
gadgets = ["Batarang", "Smoke Pellets", "Explosive Gel"]
inventory = {}

for gadget in gadgets:
    inventory[gadget] = 5  # Initial stock of each gadget

print("Utility belt inventory managed by Alfred:", inventory)
# Out:
# Utility belt inventory managed by Alfred: {'Batarang': 5, 'Smoke Pellets': 5, 'Explosive Gel': 5}

# %% [markdown]
# Abstraction, as demonstrated through functions, conditionals, and loops, allows Batman and his allies to focus on the bigger picture—be it solving crimes or saving Gotham—without getting bogged down by the underlying complexities. In programming, abstraction serves a similar purpose, enabling us to write cleaner, more modular, and more understandable code.

# %% [markdown]
# ## Big Idea: Searching
#
# Searching is a fundamental operation, both in the realm of computer science and in the tactical operations of Batman and his allies. Whether it's Oracle searching through databases to find crucial information or Batman scanning Gotham's skyline for signs of trouble, the efficiency of the search process is paramount. In programming, two classic algorithms for searching are Linear Search and Binary Search, each with its own time complexity, often expressed using Big O Notation.
#
# ### Linear Search: The Street-Level Investigation
#
# Linear search is the most straightforward searching algorithm. It involves scanning each element in a list one by one until the target is found. This is akin to Batman patrolling the streets of Gotham, checking each alley and corner for criminal activity.

# %%
# Function for linear search
def linear_search(arr, target):
    for i, item in enumerate(arr):
        if item == target:
            return i
    return -1

# Example with Batman searching for a suspect
suspects = ["Joker", "Two-Face", "Penguin"]
result = linear_search(suspects, "Joker")
print(f"Suspect found at index {result}.")

# %% [markdown]
# The time complexity for linear search is $O(n)$, where n is the number of elements in the list. In the worst-case scenario, every element must be checked.
#
# ### Binary Search: The High-Tech Scan
#
# Binary search is a more efficient algorithm but requires that the list be sorted. It repeatedly divides the list in half until the target is found, much like how Oracle might use advanced algorithms to narrow down a search field.

# %%
# Function for binary search
def binary_search(arr, target):
    low, high = 0, len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return -1

# Example with Oracle searching for a code
codes = [101, 102, 103, 104, 105]
result = binary_search(codes, 104)
print(f"Code found at index {result}.")

# %% [markdown]
# The time complexity for binary search is $O(log_n)$, making it significantly faster for large lists. However, it requires that the list be sorted ahead of time.
#
# ### Big O Notation: The Efficiency Metric
#
# Big O Notation provides a high-level understanding of the time complexity of an algorithm, abstracting away the lower-level operations and constants. It gives us a way to talk about how the runtime of an algorithm grows as the size of the input increases.
#
# -   $O(n)$: Linear time complexity, as seen in linear search.
# -   $O(log_n)$: Logarithmic time complexity, as seen in binary search.
#
# Understanding the mechanics of searching algorithms and their efficiencies allows Batman and his allies to choose the most effective strategy for their operations. Similarly, knowing when to use linear or binary search, and understanding their time complexities, can significantly impact the efficiency of a Python program.

# %% [markdown]
# ## Big Ideas: Sorting
#
# Sorting is a foundational concept in computer science, akin to organizing a toolkit for immediate and effective use. For Batman and his team, sorting could be likened to arranging gadgets in the utility belt for quick access or Oracle categorizing data for efficient retrieval. Two classic sorting algorithms often discussed are Bubble Sort and Quick Sort, each with its own time complexity, commonly expressed in Big O Notation.
#
# ### Bubble Sort: The Basic Organization
#
# Bubble Sort is one of the simplest sorting algorithms. It repeatedly steps through the list, compares adjacent elements, and swaps them if they are in the wrong order. This is similar to how Alfred might organize Batman's utility belt, carefully placing each gadget in its designated slot.

# %%
# Function for bubble sort
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

# Example with Alfred sorting the utility belt
gadgets = [3, 1, 4, 1, 5, 9, 2, 6, 5]
bubble_sort(gadgets)
print(f"Utility belt sorted by Alfred: {gadgets}")
# Out:
# Utility belt sorted by Alfred: [1, 1, 2, 3, 4, 5, 5, 6, 9]

# %% [markdown]
# ![mermaid-diagram-2023-10-29-075100.png](data:image/png;base64,...)

# %% [markdown]
# ### Quick Sort: The Strategic Arrangement
# Quick Sort is a more advanced sorting algorithm that employs a divide-and-conquer strategy. It partitions the array into smaller arrays around a "pivot" element, then sorts each smaller array. This is akin to how Oracle might categorize large datasets into smaller, more manageable chunks for quick access.

# %%
# Function for quick sort
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# Example with Oracle sorting data
data = [3, 6, 8, 10, 1, 2, 1]
sorted_data = quick_sort(data)
print(f"Data sorted by Oracle: {sorted_data}")
# Out:
# Data sorted by Oracle: [1, 1, 2, 3, 6, 8, 10]

# %% [markdown]
# ### Big O Notation: Measuring Efficiency
#
# Big O Notation serves as a metric for evaluating the efficiency of algorithms, particularly their time complexity. It abstracts away the lower-level operations to provide a high-level understanding of how an algorithm performs as the size of the input grows.
#
# -  $O(n^2)$: Quadratic time complexity, as seen in Bubble Sort.
# -  $O(n \times log_n)$: Log-linear time complexity, as seen in Quick Sort.
#
# Understanding sorting algorithms and their efficiencies enables Batman and his allies to optimize their strategies and resources. Similarly, choosing the right sorting algorithm can significantly impact the performance and efficiency of a Python program.

# %% [markdown]
# ## Alfred on Cybersecurity in Python: A Comprehensive Guide
#
# In the labyrinthine world of cyberspace, akin to the shadowy alleys of Gotham City, the need for vigilance is ever-present. I am Alfred Pennyworth, and I find it imperative to delve deeper into the intricacies of cybersecurity, especially within the context of Python programming. Let us embark on this intellectual journey.
#
# ### CIA Triad
# The bedrock of cybersecurity is the CIA Triad---Confidentiality, Integrity, and Availability.
#
# -   **Confidentiality--** This principle ensures that data is accessible only to those with authorized access. It's akin to the biometric scans that secure the Batcave.
# -   **Integrity--** This guarantees that data remains unaltered during transmission or storage. Imagine if Batman's utility belt malfunctioned; the consequences could be dire.
# -   **Availability--** This ensures that data and services are accessible when needed. Just as I ensure that the Batmobile is always ready for action, load balancers and redundancy can be implemented to guarantee service availability.
#
#
# ### Encryption
# Encryption is the act of converting data into a code to prevent unauthorized access.
#
# -   **Symmetric Encryption--* Here, a single key is used for both encryption and decryption. It's like having a single, secure password that both locks and unlocks a safe. Python's `pycrypto` library offers support for standard **AES** encrpytion.
# -   **Asymmetric Encryption--** This method utilizes a pair of keys---public and private. The public key encrypts the data, and the private key decrypts it. It's akin to a two-step verification process. Python's `rsa` library can be used to support **RSA** encrpytion.
#
#
# ### Injection Attacks and Input Validation
# Injection attacks are a nefarious method where untrusted data is sent as part of a command or query, potentially leading to unauthorized access or data loss. Input validation is your first line of defense. Just as I scrutinize every individual who wishes to enter Wayne Manor, your program should meticulously validate all input. Python libraries like `re` for regular expressions can be employed to validate text inputs, and `psycopg2` can parameterize SQL queries to prevent SQL injection.
#
# ### Hashnig
# Hashing transforms data into a fixed-size string of characters, typically a digest that represents the data. Unlike encryption, hashing is a one-way function; the original data can't be retrieved from the hash. This is particularly useful for securely storing passwords. Python's `hashlib` library offers a variety of hashing algorithms like SHA-256.
#
# By adhering to these principles and employing these Python libraries and techniques, you can construct a digital fortress as impregnable as the Batcave itself. In the perilous landscape of cyberspace, a well-prepared programmer is akin to a well-equipped Batman---a formidable defense against the ever-looming threats.

# %% [markdown]
# ## Sample Program: Make a Superhero Card
# To illustrate some of the ideas we've been talking about, here is a python program to generate a "superhero card". In the practice exercises, you'll have a chance to add on to it.
#
# We'll beging by defining some "helper" functions, and then the main program:

# %%
import random

# Helper Function to validate name input
def get_valid_name(prompt):
    while True:
        name = input(prompt)
        if name.isalpha():
            return name
        else:
            print("Invalid input. Please enter a name consisting of alphabetic characters.")

# Uncomment to test this function
# get_valid_name("What's your name?")

# %%
# Helper Function to validate number input
def get_valid_number(prompt):
    while True:
        num = input(prompt)
        if num.isdigit():
            return int(num)
        else:
            print("Invalid input. Please enter a numerical value.")

# Uncomment to test this function
# get_valid_number("What is your favorite number?")

# %%
# Helper Function to generate superhero card
def generate_superhero_card(name, num):
    superhero_prefix = ["Night", "Solar", "Quantum", "Mystic"]
    superhero_suffix = ["Falcon", "Phoenix", "Tiger", "Raven"]
    powers = ["Telekinesis", "Time Manipulation", "Super Strength", "Invisibility"]
    arch_nemesis = ["Dr. Chaos", "Lady Vortex", "Emperor Shadow", "Queen Venom"]

    superhero_name = random.choice(superhero_prefix) + " " + random.choice(superhero_suffix)
    power = random.choices(powers, k=num)
    nemesis = random.choice(arch_nemesis)

    card = f"""
    ------------------------------
    Superhero Card for {name}
    ------------------------------
    Superhero Name: {superhero_name}
    Powers: {', '.join(power)}
    Arch Nemesis: {nemesis}
    ------------------------------
    """
    return card

# %%
# Main program
def superhero():
    user_name = get_valid_name("Enter your name: ")
    num_powers = get_valid_number("Enter the number of powers you'd like (1-4): ")

    # Ensure the number of powers is within the range
    while num_powers < 1 or num_powers > 4:
        print("Invalid number of powers. Please choose between 1 and 4.")
        num_powers = get_valid_number("Enter the number of powers you'd like (1-4): ")

    superhero_card = generate_superhero_card(user_name, num_powers)
    print(superhero_card)

# Run the program
superhero()
# Out:
# Enter your name: Brendan
# Enter the number of powers you'd like (1-4): 3
#
#     ------------------------------
#     Superhero Card for Brendan
#     ------------------------------
#     Superhero Name: Solar Falcon
#     Powers: Telekinesis, Time Manipulation, Invisibility
#     Arch Nemesis: Lady Vortex
#     ------------------------------

# %% [markdown]
# ## Review with Quizlet
# Click on the following cell to launch the quizlet deck for this chapter.

# %%
# %%html
# <iframe src="https://quizlet.com/845810656/learn/embed?i=psvlh&x=1jj1" height="600" width="100%" style="border:0"></iframe>
# Out:
# <iframe src="https://quizlet.com/845810656/learn/embed?i=psvlh&x=1jj1" height="600" width="100%" style="border:0"></iframe>

# %% [markdown]
# ## Practice Exercises
# To practice your python skills, try expanding on this program in the following ways. (NOTE: You don't need to submit these for a grade).
#
# ### Exercise 1: Add a Superhero Origin City
# - Modify the program to include a superhero origin city in the superhero card.
# - Hint: Create a list of fictional cities and use random.choice() to select one. Add this to the generate_superhero_card function and update the printed card accordingly.
#
# ### Exercise 2: Validate the Origin City
# - Allow the user to input their preferred origin city, but validate it against a list of acceptable fictional cities.
# - Hint: Use a while loop similar to the name and number validation functions. Create a list of acceptable cities and check the user input against this list.
#
# ### Exercise 3: Multiple Arch-Nemesis Options:
# - Instead of having just one arch-nemesis, allow for the possibility of multiple arch-nemesis characters.
# - Hint: Modify the arch_nemesis list and use random.choices() with the k parameter to select multiple arch-nemesis characters. Update the generate_superhero_card function to handle this new format.
#
# ### Exercise 4 (Challenge): Powers Based on Origin City:
# - Make the powers available to a superhero dependent on their origin city.
# - Create separate lists of powers for each city. Use a for loop and conditionals to match the user's or randomly selected city to the appropriate list of powers.
#
# ### Exercise 5 (Challenge): Limit Total Number of Powers and Arch-Nemeses:
# - Add a constraint that the total number of powers and arch-nemeses combined should not exceed a certain limit.
# - Hint: After generating the powers and arch-nemeses, use a for loop and conditionals to check that the total number doesn't exceed the limit. If it does, remove elements from either list until the constraint is satisfied.

# %%
# Exercise 1

# %%
# Exercise 2

# %%
# Exercise 3

# %%
# Exercise 4

# %%
# Exercise 5

# %% [markdown]
# | Term | Definition and Example |
# | --- | --- |
# | Confidentiality | The principle of ensuring that unauthorized entities cannot access sensitive information. Example: When Batman communicates with Oracle, he uses a secure channel that only allows Oracle and Alfred to decipher the message. This ensures that adversaries like the Joker cannot eavesdrop on their strategic plans. |
# | Integrity | The assurance that data remains unaltered and trustworthy during storage, transmission, or processing. Example: Alfred uses cryptographic signatures to confirm that the tactical advice he sends to Batman hasn't been tampered with by Two-Face or any other villain. |
# | Availability | The assurance that resources are accessible to authorized users when needed. Example: Oracle ensures that the Batcomputer is always operational, even during a city-wide blackout orchestrated by the Penguin, so that Batman can access crucial data at any time. |
# | Symmetric Encryption | A cryptographic method where the same key is used for both encryption and decryption. Example: Cat Woman steals a device from Wayne Enterprises that uses a single key to both lock and unlock a safe. She must now find this key to access the valuables inside. |
# | Asymmetric Encryption | A cryptographic technique that uses a pair of keys: one for encryption and another for decryption. Example: Batman sends Oracle a message encrypted with her public key. Only Oracle, who possesses the corresponding private key, can decrypt it. |
# | Firewall | A network security system that monitors and filters incoming and outgoing traffic based on predetermined rules. Example: Alfred sets up a firewall to block all incoming connections from the Riddler's known IP addresses, preventing him from gaining access to the Batcave's internal network. |
# | SQL Injection | A code injection technique used to attack data-driven applications by inserting malicious SQL statements into an entry field. Example: Cat Woman tries to access Gotham City's police database by entering a malicious SQL query into the search bar, hoping to manipulate the database to erase her criminal records. |
# | Virus | Malicious software that attaches itself to clean files and spreads to other files and systems. Example: The Scarecrow releases a virus into Gotham's mainframe, corrupting files and causing widespread panic. Batman and Oracle must isolate and remove the infected files. |
# | Hashing | The process of converting data into a fixed-size string of characters, which is typically a digest representing the data. Example: To verify the integrity of a file, Batman hashes it and compares this value to a known good hash provided by Alfred. |
# | Trojan | Malicious software that disguises itself as legitimate software to gain access to target systems. Example: Poison Ivy sends Batman a seemingly benign software update for his Batmobile. Once installed, it grants her control over the vehicle's systems. |
# | Linear Search | A search algorithm that traverses through a dataset sequentially to find a target element. Example: Batman scans through a list of Gotham's criminals one by one to find the Joker's current alias. |
# | Binary Search | A search algorithm that divides a sorted dataset in half repeatedly until the target element is found or the whole set is exhausted. Example: Oracle quickly locates a piece of evidence in a sorted database by halving the search space with each query, eventually pinpointing the Riddler's next likely target. |
# | Bubble Sort | A sorting algorithm that repeatedly steps through a list, compares adjacent elements, and swaps them if they are in the wrong order. Example: Alfred organizes Batman's utility belt items by weight, swapping adjacent items until the heaviest are at one end and the lightest at the other. |
# | Merge Sort | A sorting algorithm that divides the unsorted list into smaller sub-lists, sorts them, and then merges them back together. Example: Batman sorts a pile of evidence into smaller categories, Oracle sorts each category, and then Alfred merges them back into a single, sorted pile. |
# | Big O | A notation used to describe the performance or complexity of an algorithm. Example: Oracle tells Batman that using a binary search will be more efficient (O(log n)) for finding a criminal in a sorted list than a linear search (O(n)). |
# | Algorithm | A set of rules or steps used to solve a problem. Example: Batman devises a strategy to capture Two-Face that involves a series of actions, each contingent on the outcome of the previous one. |
# | Function | A block of code designed to perform a specific task, which can be invoked by calling its name. Example: Oracle writes a function named `trackVillain` that takes a villain's name as input and returns their last known location. |
# | Parameter | A variable used in a function to refer to one of the pieces of data provided as input to the function. Example: In Oracle's `trackVillain` function, the villain's name serves as a parameter that dictates which database record to search for. |
# | Return Value | The output produced by a function, which can be used as an input in other parts of a program. Example: Batman calls Oracle's `trackVillain` function and receives the Joker's last known location as the return value. |
# | Library | A collection of precompiled routines that a program can use. Example: Alfred uses a cryptography library to implement secure communication channels between Batman and Oracle, rather than writing the encryption algorithms from scratch. |

# %% [markdown]
# ## Code to Know
# | Python Code | Description |
# | --- | --- |
# | `batmanGadgets = ["Batarang", "Grappling Hook"]` | Creates a list containing two strings, representing tools Batman uses. |
# | `batmanProfile = {"alias": "Bruce Wayne", "occupation": "Businessman"}` | Creates a dictionary with keys for alias and occupation, and their respective values. |
# | `print(f"The answer to '{q}' is {a}.")` | Outputs a formatted string that includes the values of variables `q` and `a`. |
# | `x = input("Enter Joker's alias: ")` | Prompts the user to enter a string and stores it in variable `x`. |
# | `x = float(input("Enter Joker's height in meters: "))` | Prompts the user to enter a string, converts it to a floating-point number, and stores it in variable `x`. |
# | `x = bool(int(input("Is Joker insane?")))` | Prompts the user to enter a string, converts it to an integer, and then to a Boolean, storing it in variable `x`. |
# | `message.upper()` | Converts all characters in the string `message` to uppercase. |
# | `message.capitalize()` | Converts the first character of the string `message` to uppercase. |
# | `message.replace('city', 'metropolis')` | Replaces all occurrences of the substring 'city' in `message` with 'metropolis'. |
# | `message.find('city')` | Returns the index of the first occurrence of the substring 'city' in `message`, or -1 if not found. |
# | `math.sqrt(16)` | Computes the square root of 16. |
# | `math.sin(math.pi / 2)` | Computes the sine of π/2. |
# | `random.randint(1, 10)` | Generates a random integer between 1 and 10, inclusive. |
# | `random.choice(heroes)` | Selects a random element from the list `heroes`. |
# | `if x == 10: # code` | Executes the code block if `x` is equal to 10. |
# | `if x > 10: # code \n else: # code` | Executes the first code block if `x` is greater than 10, otherwise executes the second code block. |
# | `if x > 10: # code \n elif x == 10: # code \n else: # code` | Executes one of three code blocks depending on the value of `x`. |
# | `if mission_type in cyborg_skills: # code` | Executes the code block if the value of `mission_type` is found in the list `cyborg_skills`. |
# | `if threat == "High" and strength < 5: # code` | Executes the code block if `threat` is "High" and `strength` is less than 5. |
# | `while x < 10: # code` | Executes the code block as long as `x` is less than 10. |
# | `while True: # code` | Executes the code block indefinitely until explicitly broken. |
# | `for gadget in batmanGadgets: # code` | Iterates through each element in the list `batmanGadgets`, executing the code block for each. |
# | `for i in range(5): # code` | Executes the code block five times, with `i` taking values from 0 to 4. |
# | `for x in range(3): \n for y in range(2): # code` | Executes the inner code block 6 times, with `x` taking values 0, 1, 2 and `y` taking values 0, 1. |
# | `len(batmanGadgets)` | Returns the number of elements in the list `batmanGadgets`. |
# | `batmanGadgets.append("Batmobile")` | Adds the string "Batmobile" to the end of the list `batmanGadgets`. |
# | `sorted(batmanGadgets)` | Returns a new list containing all elements in `batmanGadgets`, sorted. |
